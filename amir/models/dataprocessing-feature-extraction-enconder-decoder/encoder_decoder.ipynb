# %%
# !pip install rouge
# !pip install sacremoses
# !pip install transformers

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/mxochicale/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import numpy as np
import pandas as pd
import sacremoses
from transformers import pipeline, set_seed
from transformers import BioGptTokenizer, BioGptForCausalLM
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
import tensorflow as tf
import cv2
import pickle
from sklearn.model_selection import train_test_split
import time

from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, LSTM, Input, Embedding, Conv2D, Concatenate, Flatten, Add, Dropout, GRU
from tensorflow.keras.layers import Attention
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.losses import KLDivergence


import random
import datetime
from nltk.translate.bleu_score import sentence_bleu
import nltk
import warnings
warnings.filterwarnings('ignore')
import graphviz
import pydot
#import torch
import collections
import logging
import os
import pathlib
import re
import string
import sys
import time
from rouge import Rouge
from numpy import arange
# Out:
# 2023-08-04 12:06:29.839022: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-08-04 12:06:29.973073: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
###########################################
## CHANGE THIS PATHS BASED ON YOUR SYSTEM
HOME_PATH = os.path.expanduser(f'~')
USERNAME = os.path.split(HOME_PATH)[1]
REPOSITORY_PATH='repositories/budai4medtech/amir/'
FULL_REPO_PATH = HOME_PATH+'/'+REPOSITORY_PATH
FULL_DATASET_PATH = FULL_REPO_PATH  + 'datasets/'

print(f'FULL_DATASET_PATH: {FULL_DATASET_PATH}' )
dir = FULL_DATASET_PATH + 'ecgen-radiology'


# dir = "/content/drive/MyDrive/Colab Notebooks/dissertation/ecgen-radiology"
# Out:
# FULL_DATASET_PATH: /home/mxochicale/repositories/budai4medtech/amir/datasets/

# %% [markdown]
# ### multihead attention (attention layer)

# %%
def create_padding_mask(seq):
    seq = tf.cast(tf.math.equal(seq, 0), tf.float32)

  # add extra dimensions to add the padding
  # to the attention logits.
    return seq[:, tf.newaxis, tf.newaxis, :]  # (batch_size, 1, 1, seq_len)

def create_look_ahead_mask(size):
    mask = 1 - tf.linalg.band_part(tf.ones((size, size)), -1, 0)
    return mask  # (seq_len, seq_len)

# %%
def scaled_dot_product_attention(q, k, v, mask):

    """Calculate the attention weights.
     q, k, v must have matching leading dimensions.
     k, v must have matching penultimate dimension, i.e.: seq_len_k = seq_len_v.
     The mask has different shapes depending on its type(padding or look ahead)
     but it must be broadcastable for addition.

     Args:
       q: query shape == (..., seq_len_q, depth)
       k: key shape == (..., seq_len_k, depth)
       v: value shape == (..., seq_len_v, depth_v)
       mask: Float tensor with shape broadcastable
             to (..., seq_len_q, seq_len_k). Defaults to None.

     Returns:
       output, attention_weights
    """
    matmul_qk = tf.matmul(q, k, transpose_b=True)  # (..., seq_len_q, seq_len_k)

  # scale matmul_qk
    dk = tf.cast(tf.shape(k)[-1], tf.float32)
    scaled_attention_logits = matmul_qk / tf.math.sqrt(dk)

  # add the mask to the scaled tensor.
    if mask is not None:
        scaled_attention_logits += (mask * -1e9)

  # softmax is normalized on the last axis (seq_len_k) so that the scores
  # add up to 1.
    attention_weights = tf.nn.softmax(scaled_attention_logits, axis=-1)  # (..., seq_len_q, seq_len_k)

    output = tf.matmul(attention_weights, v)  # (..., seq_len_q, depth_v)

    return output, attention_weights

# %%
class MultiHeadAttention(tf.keras.layers.Layer):

    def __init__(self, d_model, num_heads):
        super(MultiHeadAttention, self).__init__()
        self.num_heads = num_heads
        self.d_model = d_model

        assert d_model % self.num_heads == 0

        self.depth = d_model // self.num_heads

        self.wq = tf.keras.layers.Dense(d_model)
        self.wk = tf.keras.layers.Dense(d_model)
        self.wv = tf.keras.layers.Dense(d_model)

        self.dense = tf.keras.layers.Dense(d_model)

    def split_heads(self, x, batch_size):
        """Split the last dimension into (num_heads, depth).
        Transpose the result such that the shape is (batch_size, num_heads, seq_len, depth)
        """
        x = tf.reshape(x, (batch_size, -1, self.num_heads, self.depth))
        return tf.transpose(x, perm=[0, 2, 1, 3])

    def call(self, v, k, q, mask):
        batch_size = tf.shape(q)[0]
        q = self.wq(q)  # (batch_size, seq_len, d_model)
        k = self.wk(k)  # (batch_size, seq_len, d_model)
        v = self.wv(v)  # (batch_size, seq_len, d_model)
        q = self.split_heads(q, batch_size)  # (batch_size, num_heads, seq_len_q, depth)
        k = self.split_heads(k, batch_size)  # (batch_size, num_heads, seq_len_k, depth)
        v = self.split_heads(v, batch_size)  # (batch_size, num_heads, seq_len_v, depth)
        # scaled_attention.shape == (batch_size, num_heads, seq_len_q, depth)
       # attention_weights.shape == (batch_size, num_heads, seq_len_q, seq_len_k)
        scaled_attention, attention_weights = scaled_dot_product_attention(
            q, k, v, mask)
        scaled_attention = tf.transpose(scaled_attention, perm=[0, 2, 1, 3])  # (batch_size, seq_len_q, num_heads, depth)
        concat_attention = tf.reshape(scaled_attention,
                                  (batch_size, -1, self.d_model))  # (batch_size, seq_len_q, d_model)
        output = self.dense(concat_attention)  # (batch_size, seq_len_q, d_model)


        return output, attention_weights

# %% [markdown]
# ## load dataset and defined function

# %%
## load the dataset generated from DataPreprocessing_and_Image_feature_generating notebook
# train_dataset = pd.read_csv('/content/drive/MyDrive/dissertation/Train_Data.csv')
# test_dataset = pd.read_csv('/content/drive/MyDrive/dissertation/Test_Data.csv')
# cv_dataset = pd.read_csv('/content/drive/MyDrive/dissertation/CV_Data.csv')

train_dataset = pd.read_csv('Train_Data.csv')
test_dataset = pd.read_csv('Test_Data.csv')
cv_dataset = pd.read_csv('CV_Data.csv')

# %%
# test_dataset.loc[test_dataset["Person_id"]=="image/CXR2558_IM-1062_0"]
# print(FULL_DATASET_PATH)
# test_dataset.loc[test_dataset["Person_id"]==FULL_DATASET_PATH+"/ecgen-radiology/CXR2558_IM-1062_0"]
test_dataset.loc[test_dataset["ePerson_id"]=="/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR4_IM-2050_0"]
                                             # /home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/
# test_dataset.loc[test_dataset["Person_id"]==FULL_DATASET_PATH+"/ecgen-radiology/CXR2558_IM-1062_0"]
#test_dataset.head(10)


# {'/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR4_IM-2050_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
# Out:
# Empty DataFrame
# Columns: [Person_id, Image1, Image2, Report]
# Index: []

# %%
# test_dataset[:10]FULL_DATASET_PATH+"/ecgen-radiology/CXR3980_IM-2039_0"

# %%
train_dataset.shape, test_dataset.shape, cv_dataset.shape
# Out:
# ((2776, 4), (389, 4), (542, 4))

# %%
pad_size = 153   # Max length of reports (check in the reprocessing notebook)
X_train, X_test, X_cv = train_dataset['Person_id'], test_dataset['Person_id'], cv_dataset['Person_id'][:546]
y_train, y_test, y_cv = train_dataset['Report'], test_dataset['Report'], cv_dataset['Report'][:546]

# %%
#token reports
tokenizer = Tokenizer(filters='!"#$%&()*+,-/:;<=>?@[\\]^_`{|}~\t\n')
tokenizer.fit_on_texts(y_train.values)

# %%
# load the image features generated from DataPreprocessing_and_Image_feature_generating notebook
# f = open('/content/drive/MyDrive/dissertation/Image_features_attention.pickle','rb') 
f = open('Image_features_attention.pickle','rb') 
Xnet_Features = pickle.load(f)
f.close()

# %%
Xnet_Features
# Out:
# {'/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR4_IM-2050_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[5.7846726e-05, 1.2472467e-03, 2.2824381e-03, ...,
#           8.7942016e-01, 8.4973067e-01, 7.2556263e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR3265_IM-1551_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[3.3803939e-04, 1.7989282e-03, 1.4983866e-03, ...,
#           8.6510259e-01, 8.2843202e-01, 7.1093118e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR3044_IM-1418_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[0.        , 0.00128717, 0.00113156, ..., 0.8683932 ,
#           0.8551908 , 0.7075636 ]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR2937_IM-1339_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[6.1392481e-04, 1.6862195e-03, 1.4094124e-03, ...,
#           8.8287121e-01, 8.3027196e-01, 7.2591811e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR1222_IM-0150_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[2.3180633e-04, 1.8178029e-03, 2.6350827e-03, ...,
#           8.3446759e-01, 8.6571240e-01, 6.8207914e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR3273_IM-1554_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[5.7484640e-04, 2.2024862e-03, 3.0544470e-03, ...,
#           8.0175340e-01, 8.2209796e-01, 6.5831125e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR2920_IM-1323_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[4.0164992e-04, 1.9789687e-03, 3.0484339e-03, ...,
#           8.6212915e-01, 8.4846342e-01, 7.0403695e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR2805_IM-1235_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[4.5889636e-04, 2.0974495e-03, 1.1653886e-03, ...,
#           8.6859637e-01, 8.3855802e-01, 7.0701259e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR1359_IM-0233_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[1.8304898e-04, 1.4516825e-03, 1.4751415e-03, ...,
#           8.2589883e-01, 8.2113677e-01, 6.8143737e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR491_IM-2111_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[1.7141941e-04, 1.3588013e-03, 4.1034552e-03, ...,
#           8.3837426e-01, 8.2361561e-01, 6.8467814e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR1547_IM-0357_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[5.7768053e-04, 1.7130481e-03, 2.8023343e-03, ...,
#           8.3922118e-01, 8.1175965e-01, 6.9120681e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR3724_IM-1860_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[9.6896902e-06, 9.0815919e-04, 1.2257401e-03, ...,
#           8.6909389e-01, 8.6656106e-01, 7.0527428e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR2479_IM-1007': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[3.2696746e-05, 1.3379739e-03, 2.0933377e-03, ...,
#           8.5196209e-01, 8.0418670e-01, 6.9421649e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR3408_IM-1648_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[7.3565991e-04, 1.4526168e-03, 3.6373141e-03, ...,
#           7.7387279e-01, 8.3015078e-01, 6.3432902e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR2209_IM-0816_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[1.2581763e-04, 1.8632144e-03, 1.9720371e-03, ...,
#           8.5106504e-01, 8.2454151e-01, 6.9931841e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR483_IM-2107_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[5.9572712e-04, 1.4512641e-03, 1.6540647e-03, ...,
#           8.6434042e-01, 8.4788877e-01, 7.0827812e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR2771_IM-1213_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[3.3082132e-04, 2.0691799e-03, 2.1183013e-03, ...,
#           8.3096033e-01, 8.0500650e-01, 6.8536448e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR3325_IM-1591_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[4.9057172e-04, 1.6814414e-03, 2.0192955e-03, ...,
#           8.8502783e-01, 8.4630561e-01, 7.1785003e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR2427_IM-0969_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[4.3313092e-04, 1.8398194e-03, 3.3554600e-03, ...,
#           7.6536340e-01, 8.4903812e-01, 6.2805146e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR2897_IM-1299_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[2.6440082e-04, 1.4601090e-03, 2.6653626e-03, ...,
#           8.8257927e-01, 8.4230036e-01, 7.1735018e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR107_IM-0049_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[2.5161557e-04, 1.9654103e-03, 1.8658773e-03, ...,
#           8.1909007e-01, 8.4505737e-01, 6.6962796e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR3034_IM-1408_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[5.2976212e-04, 1.5945286e-03, 1.6179135e-03, ...,
#           8.1676608e-01, 8.3400834e-01, 6.6665041e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR2924_IM-1327_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[5.1179010e-04, 1.9093902e-03, 1.9564577e-03, ...,
#           7.9958266e-01, 8.2921398e-01, 6.5948105e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR2070_IM-0704_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[3.8441696e-04, 1.6375994e-03, 2.1403476e-03, ...,
#           8.2368171e-01, 8.6221290e-01, 6.7994612e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR3770_IM-1890_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[2.7890911e-04, 1.6257516e-03, 1.9503754e-03, ...,
#           8.5975516e-01, 8.2715434e-01, 7.0138377e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR2787_IM-1222_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[4.9931911e-04, 1.4232110e-03, 1.6656122e-03, ...,
#           8.1231964e-01, 8.3702850e-01, 6.6516238e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR609_IM-2197_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[5.1793474e-04, 1.5616977e-03, 1.7488436e-03, ...,
#           8.1857741e-01, 8.2190955e-01, 6.7035061e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR3924_IM-1998': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[4.1299377e-06, 1.0564032e-03, 1.4713666e-03, ...,
#           7.7533728e-01, 8.3306485e-01, 6.3187307e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR291_IM-1313_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[1.3353195e-04, 1.4555696e-03, 1.1470045e-03, ...,
#           8.5248768e-01, 8.1711507e-01, 6.9149190e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR2618_IM-1107_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[5.9890253e-06, 1.3900072e-03, 1.7170704e-03, ...,
#           8.0950552e-01, 8.9877605e-01, 6.5704548e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR1124_IM-0081_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[3.6783682e-04, 1.7837061e-03, 2.4240536e-03, ...,
#           7.8961843e-01, 8.3219761e-01, 6.4920801e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR3027_IM-1402': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[1.1248788e-04, 1.7994373e-03, 1.2212201e-03, ...,
#           8.7513673e-01, 8.5839814e-01, 7.1899462e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR2275_IM-0862_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[3.6755280e-04, 1.4986139e-03, 4.4898358e-03, ...,
#           8.2269067e-01, 8.1744999e-01, 6.7929059e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR3943_IM-2013': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[2.7592038e-04, 1.4020448e-03, 2.4842902e-03, ...,
#           8.4494245e-01, 8.7292916e-01, 6.8765962e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR970_IM-2460_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[5.5636885e-04, 1.6850055e-03, 1.6034046e-03, ...,
#           8.1920820e-01, 8.1271923e-01, 6.7133719e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR2166_IM-0782': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[3.5564130e-04, 1.9234380e-03, 2.5453302e-03, ...,
#           8.0095977e-01, 8.8896984e-01, 6.5961474e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR168_IM-0448_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[4.2472838e-04, 1.0707357e-03, 2.5206222e-03, ...,
#           8.1009859e-01, 8.1647050e-01, 6.6300708e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR1502_IM-0328_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[5.2211888e-04, 1.9779282e-03, 1.7255136e-03, ...,
#           8.0112129e-01, 8.5172963e-01, 6.5638942e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR3464_IM-1683_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[3.1962199e-04, 1.7557903e-03, 2.2135619e-03, ...,
#           8.8845241e-01, 8.2904011e-01, 7.2935712e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR2021_IM-0668_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[6.8109797e-04, 1.8000061e-03, 3.1855893e-03, ...,
#           7.9825741e-01, 8.3434325e-01, 6.5715122e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR1126_IM-0082_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[2.4471674e-04, 1.9614743e-03, 2.8393487e-03, ...,
#           8.3442831e-01, 8.3676410e-01, 6.8180484e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR1388_IM-0246_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[4.2072669e-04, 2.1616314e-03, 1.9616515e-03, ...,
#           8.1595129e-01, 8.3015746e-01, 6.6835284e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR581_IM-2178_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[5.7526422e-04, 1.6964003e-03, 1.6093830e-03, ...,
#           8.2180506e-01, 8.6619359e-01, 6.7215782e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR2848_IM-1256_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[5.6233665e-04, 1.9430509e-03, 2.0774640e-03, ...,
#           7.7717483e-01, 8.1925660e-01, 6.3432497e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR2562_IM-1065_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[3.1286784e-04, 1.3567641e-03, 2.6676042e-03, ...,
#           7.8254062e-01, 8.1211346e-01, 6.3973826e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR1506_IM-0330_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[4.8975652e-04, 1.5426020e-03, 1.7807478e-03, ...,
#           8.3976585e-01, 8.2655543e-01, 6.8651354e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR254_IM-1051_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[2.5098023e-04, 1.9235705e-03, 1.7418911e-03, ...,
#           8.1122839e-01, 8.2201201e-01, 6.6451085e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR1867_IM-0560_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[0.        , 0.00162421, 0.00181117, ..., 0.8709425 ,
#           0.85086924, 0.7199069 ]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR1489_IM-0315_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[4.2577335e-04, 2.1230467e-03, 2.0046050e-03, ...,
#           8.8972557e-01, 8.4668273e-01, 7.2478074e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR543_IM-2148_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[4.4461188e-04, 2.0306157e-03, 2.0033282e-03, ...,
#           8.1675661e-01, 8.4516418e-01, 6.6936576e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR3343_IM-1603': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[3.8697879e-05, 1.6571640e-03, 1.8610605e-03, ...,
#           8.3912581e-01, 8.8812721e-01, 6.8414664e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR657_IM-2233-0001_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[0.0009375 , 0.00149428, 0.00149526, ..., 0.8437022 ,
#           0.8206831 , 0.6867582 ]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR3774_IM-1892_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[4.3106213e-04, 1.2064575e-03, 1.8407220e-03, ...,
#           7.9211086e-01, 8.3655143e-01, 6.5452254e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR541_IM-2147': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[1.4999404e-04, 1.2581295e-03, 1.7289360e-03, ...,
#           9.0441573e-01, 8.1263971e-01, 7.3153001e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR3935_IM-2006_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[0.00105437, 0.00121802, 0.00458956, ..., 0.8247821 ,
#           0.8245941 , 0.6746762 ]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR139_IM-0248_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[9.6222800e-05, 1.7866116e-03, 2.8795623e-03, ...,
#           8.5342580e-01, 8.2098854e-01, 6.9863492e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR3513_IM-1715': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[2.2447480e-04, 1.7780017e-03, 1.5095911e-03, ...,
#           8.8451743e-01, 8.5409260e-01, 7.2209024e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR3731_IM-1865_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[6.5358548e-04, 1.3129809e-03, 2.3959558e-03, ...,
#           8.2267237e-01, 8.3687311e-01, 6.7213190e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR3446_IM-1669_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[7.6695415e-04, 1.8172370e-03, 1.6997244e-03, ...,
#           7.9034454e-01, 8.5265708e-01, 6.4544332e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR1951_IM-0619_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[3.5943207e-04, 1.4046237e-03, 2.0909661e-03, ...,
#           7.7728313e-01, 8.6575639e-01, 6.3505101e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR3302_IM-1579_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[2.6499433e-04, 1.5411091e-03, 1.9095440e-03, ...,
#           8.0713212e-01, 8.4179187e-01, 6.5754747e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR750_IM-2304_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[7.0136366e-04, 1.5695327e-03, 1.9208163e-03, ...,
#           8.6063468e-01, 8.2473987e-01, 7.0318967e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR715_IM-2277_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[5.3307979e-04, 9.4938709e-04, 3.0194514e-03, ...,
#           8.2596630e-01, 8.3415627e-01, 6.7430174e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR518_IM-2131_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[6.1563456e-05, 1.7067754e-03, 3.6030593e-03, ...,
#           7.9052740e-01, 8.3370316e-01, 6.5071744e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR204_IM-0683': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[3.8691776e-04, 2.0022900e-03, 1.1418271e-03, ...,
#           9.0879846e-01, 8.9741331e-01, 7.3626280e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR660_IM-2237-0001_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[1.6130904e-04, 1.1202717e-03, 1.2416479e-03, ...,
#           8.2564688e-01, 8.4400862e-01, 6.7084527e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR1585_IM-0380_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[5.4777972e-04, 1.4009486e-03, 1.9780961e-03, ...,
#           8.5806471e-01, 8.3191675e-01, 7.0330435e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR2481_IM-1010': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[6.5407725e-08, 1.1941756e-03, 1.1807141e-03, ...,
#           8.6349112e-01, 8.3173013e-01, 7.1066922e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR2904_IM-1308_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[4.6128395e-04, 1.1748775e-03, 2.7529227e-03, ...,
#           8.0206853e-01, 8.2786757e-01, 6.5308666e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR1235_IM-0158_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[5.2164402e-04, 1.2883132e-03, 1.5772859e-03, ...,
#           8.5939085e-01, 8.1669676e-01, 7.0019633e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR3190_IM-1505_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[2.0380884e-04, 1.4192165e-03, 1.8412814e-03, ...,
#           7.9702497e-01, 8.1828189e-01, 6.6088974e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR725_IM-2285_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[2.8182345e-04, 1.5831291e-03, 2.4863645e-03, ...,
#           8.3032566e-01, 8.7714213e-01, 6.8545657e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR725_IM-2285_1': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[2.8182345e-04, 1.5831291e-03, 2.4863645e-03, ...,
#           7.6965833e-01, 8.3924997e-01, 6.4533293e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR725_IM-2285_2': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[2.7532526e-04, 2.0914047e-03, 2.3723578e-03, ...,
#           7.6965833e-01, 8.3924997e-01, 6.4533293e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR1600_IM-0390_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[1.2947241e-04, 2.1534516e-03, 9.8760973e-04, ...,
#           7.7170134e-01, 8.2843786e-01, 6.3249367e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR2632_IM-1119_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[6.7869731e-04, 1.5631334e-03, 1.5531116e-03, ...,
#           8.7153316e-01, 8.2465714e-01, 7.1141839e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR1149_IM-0101_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[2.1835075e-04, 1.6624837e-03, 1.7161721e-03, ...,
#           9.0001267e-01, 8.5884547e-01, 7.3048753e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR2571_IM-1073': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[4.4612541e-05, 1.3197061e-03, 1.2991211e-03, ...,
#           8.6740774e-01, 8.2669473e-01, 7.0758218e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR1364_IM-0237_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[6.5869011e-04, 1.8909554e-03, 1.3645876e-03, ...,
#           8.4040189e-01, 8.3563596e-01, 6.7637414e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR2197_IM-0807_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[4.0363052e-04, 1.8262848e-03, 1.7139997e-03, ...,
#           8.2483846e-01, 8.3964115e-01, 6.7899859e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR1709_IM-0467_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[5.9047679e-04, 9.8999182e-04, 2.0317005e-03, ...,
#           8.4638190e-01, 8.4135306e-01, 6.9641656e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR2644_IM-1130_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[8.347795e-08, 2.125378e-03, 1.304698e-03, ..., 7.697332e-01,
#           8.305143e-01, 6.288664e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR3260_IM-1547_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[3.7244221e-04, 1.2558796e-03, 4.2855376e-03, ...,
#           8.3799773e-01, 8.1583345e-01, 6.8569010e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR415_IM-2058_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[3.1671213e-04, 1.5153884e-03, 1.1571154e-03, ...,
#           8.2530069e-01, 8.2621771e-01, 6.8306816e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR2505_IM-1029_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[4.4886069e-04, 1.6751244e-03, 2.2372105e-03, ...,
#           8.3113074e-01, 8.3191729e-01, 6.8124431e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR3926_IM-2000_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[0.        , 0.00137527, 0.00168901, ..., 0.8379354 ,
#           0.83407754, 0.68852854]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR1075_IM-0054_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[4.3011009e-04, 9.5085212e-04, 3.8083864e-03, ...,
#           7.8589475e-01, 8.4279752e-01, 6.4500517e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR3644_IM-1807_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[2.6368922e-05, 1.4469395e-03, 2.3787383e-03, ...,
#           8.0989695e-01, 8.1891561e-01, 6.6097689e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR2942_IM-1343_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[1.2470258e-04, 1.5809947e-03, 2.8083927e-03, ...,
#           8.6623555e-01, 8.1161112e-01, 7.0656276e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR2984_IM-1372': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[6.1295141e-05, 1.7434612e-03, 1.6935142e-03, ...,
#           8.5009885e-01, 8.4348601e-01, 6.9395119e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR801_IM-2335_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[4.8931706e-04, 1.7567730e-03, 1.3766707e-03, ...,
#           8.3365232e-01, 8.5452116e-01, 6.8229592e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR861_IM-2382_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[1.3192698e-04, 1.6252314e-03, 1.4950786e-03, ...,
#           8.3602822e-01, 8.5958666e-01, 6.8554986e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR2243_IM-0840_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[4.0266971e-04, 1.4768833e-03, 2.4718239e-03, ...,
#           8.0812633e-01, 8.2530713e-01, 6.6069263e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR2243_IM-0840_1': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[4.0266971e-04, 1.4768833e-03, 2.4718239e-03, ...,
#           7.7201444e-01, 8.2067853e-01, 6.3117146e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR2243_IM-0840_2': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[4.0266971e-04, 1.4768833e-03, 2.4718239e-03, ...,
#           8.5645044e-01, 8.4670216e-01, 7.0130891e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR2243_IM-0840_3': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[7.0197450e-05, 1.0414305e-03, 1.9060589e-03, ...,
#           7.7201444e-01, 8.2067853e-01, 6.3117146e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR2243_IM-0840_4': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[7.0197450e-05, 1.0414305e-03, 1.9060589e-03, ...,
#           8.5645044e-01, 8.4670216e-01, 7.0130891e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR2243_IM-0840_5': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[6.5391752e-05, 8.4265019e-04, 1.9330848e-03, ...,
#           8.5645044e-01, 8.4670216e-01, 7.0130891e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR2665_IM-1145_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[4.4356857e-04, 1.4616956e-03, 3.1799220e-03, ...,
#           8.4201783e-01, 8.2326007e-01, 6.9118571e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR164_IM-0419_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[3.4283972e-04, 1.9310488e-03, 2.4746992e-03, ...,
#           7.9139632e-01, 8.2132393e-01, 6.5321994e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR3983_IM-2039_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[2.1389611e-04, 1.1455416e-03, 2.8315210e-03, ...,
#           8.0442613e-01, 8.4453881e-01, 6.5984219e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR1331_IM-0213': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[0.        , 0.00109955, 0.00185281, ..., 0.80817896,
#           0.8198927 , 0.66005397]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR75_IM-2303_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[3.3334779e-04, 1.3861250e-03, 4.0490106e-03, ...,
#           8.6325514e-01, 8.2728750e-01, 7.1270370e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR90_IM-2407_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[4.3525387e-04, 1.3734518e-03, 2.4522240e-03, ...,
#           8.3667529e-01, 8.3747739e-01, 6.8428826e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR3089_IM-1444_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[7.2184572e-04, 1.8859184e-03, 1.9474317e-03, ...,
#           8.2844293e-01, 8.5173142e-01, 6.7832214e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR2283_IM-0870_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[3.1316164e-04, 1.5459760e-03, 1.7691012e-03, ...,
#           7.9861838e-01, 8.4065193e-01, 6.6153824e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR2847_IM-1256_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[4.1323519e-04, 1.4376644e-03, 3.1323475e-03, ...,
#           8.3233207e-01, 8.2800293e-01, 6.8321651e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR153_IM-0343_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[2.3755412e-04, 1.1247632e-03, 4.1617914e-03, ...,
#           8.1895989e-01, 8.5559976e-01, 6.7577422e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR3661_IM-1821_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[4.4915028e-04, 1.8042098e-03, 1.9879660e-03, ...,
#           7.9921067e-01, 8.5494864e-01, 6.5218580e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR2353_IM-0918_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[2.2974034e-04, 1.7713561e-03, 2.8085886e-03, ...,
#           8.1486112e-01, 8.2863939e-01, 6.6906857e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR487_IM-2110_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[3.3465942e-05, 1.5514732e-03, 1.8612311e-03, ...,
#           8.6902440e-01, 8.2092988e-01, 7.1109003e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR2480_IM-1009_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[4.9372372e-04, 1.6868159e-03, 2.4764957e-03, ...,
#           8.2159221e-01, 8.2020897e-01, 6.7199141e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR1148_IM-0100_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[5.4930837e-04, 1.6104677e-03, 1.2719281e-03, ...,
#           8.0909956e-01, 8.1625831e-01, 6.6246176e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR2502_IM-1027-1001_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[2.8052995e-05, 1.1829864e-03, 1.9162818e-03, ...,
#           8.7175393e-01, 8.2939219e-01, 7.1121055e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR1663_IM-0439_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[5.2221661e-04, 1.7235989e-03, 1.6264792e-03, ...,
#           8.0327410e-01, 8.4058195e-01, 6.6141146e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR2807_IM-1237_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[2.6399229e-04, 1.7063399e-03, 1.7360644e-03, ...,
#           8.0341738e-01, 8.2890940e-01, 6.5634686e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR863_IM-2383_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[2.7976057e-04, 1.3148988e-03, 2.3603325e-03, ...,
#           8.0440962e-01, 8.3357978e-01, 6.6408014e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR863_IM-2383_1': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[2.7976057e-04, 1.3148988e-03, 2.3603325e-03, ...,
#           8.8305050e-01, 8.6668348e-01, 7.1775621e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR863_IM-2383_2': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[9.5258283e-06, 1.0649427e-03, 9.7558578e-04, ...,
#           8.8305050e-01, 8.6668348e-01, 7.1775621e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR2935_IM-1337_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[4.0877980e-04, 1.6184838e-03, 1.4854068e-03, ...,
#           8.4089249e-01, 8.2081473e-01, 6.8647921e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR1655_IM-0431_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[5.0308346e-04, 1.2013385e-03, 1.8921585e-03, ...,
#           7.9909635e-01, 8.3993751e-01, 6.5263855e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR284_IM-1252_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[9.5917258e-06, 9.5577515e-04, 1.4049802e-03, ...,
#           8.6598432e-01, 8.8555020e-01, 7.0557785e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR1345_IM-0223_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[2.5292422e-04, 2.0978549e-03, 1.3457789e-03, ...,
#           8.0544364e-01, 8.3481073e-01, 6.5817702e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR1422_IM-0269_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[2.9027788e-04, 8.7104534e-04, 4.7212569e-03, ...,
#           8.0844897e-01, 8.4073097e-01, 6.6588265e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR1596_IM-0387_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[3.5953039e-04, 1.8505451e-03, 6.9640420e-04, ...,
#           8.1396794e-01, 8.1253558e-01, 6.6804302e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR3223_IM-1523_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[4.0540830e-04, 1.3932507e-03, 2.4542315e-03, ...,
#           8.5700685e-01, 8.3570760e-01, 6.9798714e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR1438_IM-0282_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[5.1602331e-04, 1.9102818e-03, 1.9773291e-03, ...,
#           7.7949464e-01, 8.2323992e-01, 6.4168209e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR1469_IM-0303_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[4.2086269e-04, 1.6130114e-03, 2.6591846e-03, ...,
#           8.0289078e-01, 8.3776987e-01, 6.5408015e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR3709_IM-1852_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[1.9530917e-04, 1.3940528e-03, 2.6023649e-03, ...,
#           8.2704413e-01, 8.2991236e-01, 6.7858201e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR3709_IM-1852_1': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[1.9530917e-04, 1.3940528e-03, 2.6023649e-03, ...,
#           8.6127776e-01, 8.2586211e-01, 7.0649368e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR3709_IM-1852_2': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[0.0000000e+00, 1.2280528e-03, 6.2395702e-04, ...,
#           8.6127776e-01, 8.2586211e-01, 7.0649368e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR1381_IM-0245_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[2.7211671e-04, 1.8356444e-03, 1.9776747e-03, ...,
#           8.3178389e-01, 8.4618407e-01, 6.7969847e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR147_IM-0303': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[3.8027338e-04, 1.5176928e-03, 2.1969932e-03, ...,
#           8.7749463e-01, 8.6960584e-01, 7.2149730e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR2296_IM-0876_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[1.9697065e-04, 1.8059365e-03, 2.2735817e-03, ...,
#           7.9356408e-01, 8.3857924e-01, 6.5964043e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR1598_IM-0389_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[8.3039969e-04, 1.6705180e-03, 2.1037958e-03, ...,
#           8.0437571e-01, 8.5185498e-01, 6.6020727e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR45_IM-2081': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[2.0598411e-04, 2.0586951e-03, 2.5458189e-03, ...,
#           8.6597526e-01, 8.3659244e-01, 7.1063799e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR1271_IM-0182_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[5.9837630e-06, 1.2410133e-03, 8.4361661e-04, ...,
#           8.7324470e-01, 9.3292004e-01, 7.1736550e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR3299_IM-1575_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[2.0553246e-04, 1.6831304e-03, 1.6901648e-03, ...,
#           7.6778740e-01, 8.0945760e-01, 6.3072044e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR2148_IM-0767_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[2.3990309e-04, 2.0328623e-03, 4.2230287e-04, ...,
#           8.4994650e-01, 8.7074578e-01, 6.9528621e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR1880_IM-0569': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[5.7249400e-04, 1.4623005e-03, 2.2603250e-03, ...,
#           8.4309912e-01, 8.9447021e-01, 6.8692398e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR25_IM-1024_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[5.1135180e-04, 8.6724467e-04, 3.3661854e-03, ...,
#           8.6900932e-01, 8.4719568e-01, 7.0736873e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR3764_IM-1884_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[5.8704411e-04, 1.6537587e-03, 1.8358385e-03, ...,
#           8.3151704e-01, 8.1231481e-01, 6.8023664e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR779_IM-2321_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[2.8387317e-04, 1.9526209e-03, 1.9814114e-03, ...,
#           8.7037057e-01, 8.2451248e-01, 7.0778751e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR921_IM-2423_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[4.5687455e-04, 1.5304885e-03, 1.8567824e-03, ...,
#           8.0621713e-01, 7.9471076e-01, 6.5619540e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR534_IM-2141_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[6.8502122e-04, 1.6706855e-03, 1.4781222e-03, ...,
#           7.0250189e-01, 8.4926939e-01, 5.7823461e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR3128_IM-1471_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[6.1590801e-04, 1.6672204e-03, 1.9175147e-03, ...,
#           8.4581757e-01, 8.7349707e-01, 6.9043571e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR1978_IM-0636_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[5.5171904e-04, 1.0991654e-03, 2.7650248e-03, ...,
#           8.7738675e-01, 8.3871198e-01, 7.1667433e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR20_IM-0653_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[5.7968142e-04, 1.4608151e-03, 1.8561578e-03, ...,
#           8.0014640e-01, 8.5107327e-01, 6.6047716e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR2841_IM-1253': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[1.10712026e-04, 9.97580471e-04, 1.89145247e-03, ...,
#           8.58948529e-01, 8.17064881e-01, 7.03716815e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR39_IM-1978_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[4.3060197e-04, 1.8779432e-03, 1.3031218e-03, ...,
#           8.3031225e-01, 8.2581019e-01, 6.7890376e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR2414_IM-0960': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[1.4577461e-04, 1.3474210e-03, 1.7273473e-03, ...,
#           8.2257962e-01, 8.0968916e-01, 6.7299885e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR3431_IM-1660_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[5.4502161e-04, 1.7285000e-03, 1.2115078e-03, ...,
#           8.2902783e-01, 8.4483916e-01, 6.7942959e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR2179_IM-0791_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[3.4302217e-04, 1.3541476e-03, 3.1755120e-03, ...,
#           8.3877611e-01, 8.1276214e-01, 6.8430549e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR2200_IM-0811_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[3.0187640e-04, 1.2685367e-03, 2.0591102e-03, ...,
#           8.3065873e-01, 8.4980434e-01, 6.7918068e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR3316_IM-1586': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[3.5111918e-04, 1.8782169e-03, 1.1538602e-03, ...,
#           9.1842496e-01, 8.0284923e-01, 7.4759680e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR262_IM-1109': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[4.5840986e-04, 1.7209649e-03, 1.9876494e-03, ...,
#           8.6073762e-01, 8.2797170e-01, 7.0156956e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR3101_IM-1453_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[6.0038309e-04, 1.8702232e-03, 1.0247276e-03, ...,
#           8.1159800e-01, 8.3423305e-01, 6.6872376e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR2430_IM-0972': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[1.38550695e-05, 1.31536310e-03, 1.03796751e-03, ...,
#           8.38250637e-01, 8.20609570e-01, 6.86392725e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR3535_IM-1728-0001_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[7.4901043e-05, 9.8494242e-04, 1.5561994e-03, ...,
#           8.4548622e-01, 8.4416395e-01, 6.9330472e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR3618_IM-1790_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[6.9190620e-04, 1.1111400e-03, 2.5016465e-03, ...,
#           8.2843912e-01, 8.4303516e-01, 6.8842214e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR934_IM-2432_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[2.5157086e-04, 1.4326508e-03, 2.6066743e-03, ...,
#           8.4252977e-01, 8.2200295e-01, 6.9299424e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR1103_IM-0070_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[3.6238035e-04, 1.6135530e-03, 1.4128138e-03, ...,
#           8.4580517e-01, 8.3544165e-01, 6.9230247e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR2837_IM-1252_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[1.8691404e-04, 1.8198109e-03, 8.8208466e-04, ...,
#           8.2762611e-01, 8.4291840e-01, 6.7804611e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR169_IM-0452_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[4.6516879e-04, 1.9484757e-03, 1.6955644e-03, ...,
#           8.3888745e-01, 8.3243078e-01, 6.8499649e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR1179_IM-0122_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[6.5129844e-04, 1.6144579e-03, 2.7259910e-03, ...,
#           8.1066412e-01, 8.5521781e-01, 6.6387147e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR1358_IM-0232_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[3.2276500e-04, 1.6144146e-03, 1.7039082e-03, ...,
#           8.0474961e-01, 8.2587200e-01, 6.5884113e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR1358_IM-0232_1': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[3.2276500e-04, 1.6144146e-03, 1.7039082e-03, ...,
#           8.6362386e-01, 8.1740677e-01, 7.0488799e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR1358_IM-0232_2': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[0.        , 0.00098213, 0.00181093, ..., 0.86362386,
#           0.8174068 , 0.704888  ]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR1571_IM-0373': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[8.8149129e-05, 9.8377955e-04, 2.1045632e-03, ...,
#           8.7002695e-01, 8.1179911e-01, 7.0704526e-01]]], dtype=float32)>,
# ...
#  array([[[2.2408881e-06, 1.3942013e-03, 2.1962924e-03, ...,
#           7.8059387e-01, 8.3791965e-01, 6.3963962e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR3485_IM-1694_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[3.8859952e-04, 1.5535018e-03, 2.3565167e-03, ...,
#           8.4280956e-01, 8.3930051e-01, 6.8637919e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR797_IM-2332_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[1.00027704e-04, 1.47074717e-03, 2.24218355e-03, ...,
#           8.23952138e-01, 8.09191406e-01, 6.73740923e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR3597_IM-1775_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[6.1755523e-04, 1.7625706e-03, 2.0575277e-03, ...,
#           7.2367239e-01, 8.1714195e-01, 5.9312963e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR959_IM-2449_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[1.3418692e-05, 1.4879624e-03, 1.2349327e-03, ...,
#           8.7675738e-01, 8.2306290e-01, 7.1289265e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR1217_IM-0145-0001_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[1.1418767e-04, 1.2630186e-03, 1.4319654e-03, ...,
#           8.6036026e-01, 8.2832617e-01, 6.9463503e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR2516_IM-1036_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[4.3317201e-04, 1.6021556e-03, 2.3541010e-03, ...,
#           8.1871611e-01, 8.3334428e-01, 6.6949892e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR1204_IM-0138_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[1.9960913e-04, 1.9269068e-03, 1.5866747e-03, ...,
#           7.2234553e-01, 8.2869881e-01, 5.9646446e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR2967_IM-1360': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[5.4706912e-04, 1.7005738e-03, 1.4042081e-03, ...,
#           8.8059038e-01, 8.9127475e-01, 7.1853095e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR176_IM-0496_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[6.2318990e-04, 1.7228499e-03, 1.5202549e-03, ...,
#           8.4201247e-01, 8.2772529e-01, 6.8552524e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR1581_IM-0378_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[1.9981853e-04, 1.5798449e-03, 2.1545005e-03, ...,
#           8.1997907e-01, 8.4115374e-01, 6.7001677e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR3398_IM-1642_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[1.3221914e-05, 1.2956306e-03, 1.9062706e-03, ...,
#           8.4496969e-01, 8.6048353e-01, 6.9625676e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR1329_IM-0211_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[2.3484297e-04, 1.0647784e-03, 2.8962779e-03, ...,
#           8.8042903e-01, 8.2845646e-01, 7.1509039e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR2162_IM-0779_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[3.8457927e-04, 1.3889035e-03, 1.9624867e-03, ...,
#           8.5490948e-01, 8.1674474e-01, 6.9760036e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR2030_IM-0675_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[6.2188000e-04, 1.5816053e-03, 2.2555250e-03, ...,
#           7.9786861e-01, 8.3949602e-01, 6.5767187e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR3071_IM-1433_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[7.5026311e-04, 1.4864752e-03, 1.6315219e-03, ...,
#           8.2510167e-01, 8.2048976e-01, 6.7968494e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR3291_IM-1572_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[4.1736336e-04, 1.4731095e-03, 2.7672895e-03, ...,
#           8.2434845e-01, 8.2452518e-01, 6.7469072e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR3915_IM-1990_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[8.5913307e-05, 1.7246737e-03, 2.0086633e-03, ...,
#           8.2230878e-01, 8.2851952e-01, 6.7193204e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR3677_IM-1830_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[0.        , 0.00168209, 0.00129333, ..., 0.8882603 ,
#           0.9146343 , 0.7362154 ]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR1246_IM-0167_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[6.1580061e-04, 1.2195723e-03, 1.9026072e-03, ...,
#           9.0250456e-01, 8.3730310e-01, 7.3243129e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR152_IM-0335_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[0.        , 0.00111092, 0.00195539, ..., 0.870875  ,
#           0.8326798 , 0.7078186 ]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR2406_IM-0954_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[2.2021863e-04, 1.4174058e-03, 2.6736897e-03, ...,
#           7.9656607e-01, 8.3980995e-01, 6.5904737e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR748_IM-2302_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[5.1613944e-04, 1.8831952e-03, 2.1045126e-03, ...,
#           8.2009351e-01, 8.4522051e-01, 6.7432576e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR1770_IM-0504_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[6.6634396e-04, 1.1181656e-03, 2.7065403e-03, ...,
#           8.1551903e-01, 8.4682822e-01, 6.6574717e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR3185_IM-1503_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[5.3871470e-04, 1.7931594e-03, 2.4098817e-03, ...,
#           8.7621349e-01, 8.4710723e-01, 7.1542412e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR2007_IM-0657-0001_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[5.6694469e-05, 9.6950773e-04, 1.3286236e-03, ...,
#           8.6617082e-01, 8.6942041e-01, 7.0889658e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR3078_IM-1438_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[5.7175319e-04, 9.3775621e-04, 2.5866299e-03, ...,
#           8.3222014e-01, 8.5710883e-01, 6.8354058e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR485_IM-2109_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[5.1231612e-04, 2.0714360e-03, 1.5354881e-03, ...,
#           8.4779477e-01, 8.3412373e-01, 6.9468290e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR3809_IM-1919_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[0.00084105, 0.00183805, 0.00224512, ..., 0.80945146,
#           0.79547316, 0.6601789 ]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR3809_IM-1919_1': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[0.00084105, 0.00183805, 0.00224512, ..., 0.8261965 ,
#           0.82747096, 0.6771349 ]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR3809_IM-1919_2': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[6.3772168e-05, 1.0514326e-03, 1.3683637e-03, ...,
#           8.2619649e-01, 8.2747096e-01, 6.7713487e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR1954_IM-0622_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[7.5625844e-04, 2.1235670e-03, 1.4171492e-03, ...,
#           8.1697977e-01, 8.2625496e-01, 6.6769612e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR1000_IM-0003_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[2.6737692e-04, 1.1275912e-03, 2.5713043e-03, ...,
#           8.3283126e-01, 8.5380965e-01, 6.8379915e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR1000_IM-0003_1': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[2.6737692e-04, 1.1275912e-03, 2.5713043e-03, ...,
#           8.3857846e-01, 8.2354021e-01, 6.8696666e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR1000_IM-0003_2': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[1.0908020e-04, 1.3426032e-03, 1.0341328e-03, ...,
#           8.3857846e-01, 8.2354021e-01, 6.8696666e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR788_IM-2328_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[3.6756817e-04, 1.4090018e-03, 2.0962167e-03, ...,
#           8.7894255e-01, 8.7298262e-01, 7.1273500e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR3079_IM-1438_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[0.00093346, 0.00118486, 0.0023097 , ..., 0.8215101 ,
#           0.8129328 , 0.6706465 ]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR38_IM-1911_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[2.8822012e-04, 1.5850076e-03, 2.4809218e-03, ...,
#           8.6410987e-01, 8.3808178e-01, 7.0222551e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR718_IM-2280_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[5.1008753e-04, 1.7682618e-03, 1.7526618e-03, ...,
#           8.5605806e-01, 8.3148414e-01, 7.0102233e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR527_IM-2137': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[4.6256595e-04, 1.3345170e-03, 2.4332581e-03, ...,
#           8.0586571e-01, 8.3253241e-01, 6.5981376e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR636_IM-2215_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[3.1045094e-04, 1.1011629e-03, 2.2112962e-03, ...,
#           7.8728712e-01, 8.4076387e-01, 6.4432734e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR821_IM-2351': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[2.5901420e-04, 1.1245924e-03, 1.1581946e-03, ...,
#           8.2605761e-01, 8.8622725e-01, 6.8278742e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR1616_IM-0399_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[2.8519152e-04, 1.6091043e-03, 2.3820288e-03, ...,
#           8.4837085e-01, 8.4560972e-01, 6.9345099e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR116_IM-0107_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[1.6271266e-04, 1.6119605e-03, 1.6007393e-03, ...,
#           8.3440506e-01, 8.0981797e-01, 6.8795389e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR163_IM-0410_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[4.4459302e-04, 1.2714051e-03, 1.8293599e-03, ...,
#           8.2425225e-01, 8.2517189e-01, 6.7387879e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR163_IM-0410_1': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[4.4459302e-04, 1.2714051e-03, 1.8293599e-03, ...,
#           8.4953851e-01, 8.6180735e-01, 6.8760961e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR163_IM-0410_2': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[3.7424313e-04, 1.3993497e-03, 1.9439812e-03, ...,
#           8.4953851e-01, 8.6180735e-01, 6.8760961e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR842_IM-2366_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[5.9038121e-04, 1.4017393e-03, 2.3360692e-03, ...,
#           8.2666832e-01, 8.3154720e-01, 6.7808199e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR2565_IM-1068_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[2.5834751e-04, 1.3035042e-03, 2.9618442e-03, ...,
#           7.9612762e-01, 8.1679159e-01, 6.5143389e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR1543_IM-0353_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[2.9296218e-04, 1.5731152e-03, 2.5061721e-03, ...,
#           8.1411064e-01, 8.2935584e-01, 6.7004931e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR3964_IM-2028_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[5.7540822e-04, 1.9777380e-03, 2.7613104e-03, ...,
#           8.3833897e-01, 8.3430296e-01, 6.9223243e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR1538_IM-0348_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[4.8287536e-04, 1.8121640e-03, 1.6050057e-03, ...,
#           8.2220078e-01, 8.2155812e-01, 6.7583323e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR3477_IM-1690_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[6.2587278e-05, 1.1850357e-03, 1.4151614e-03, ...,
#           8.2789457e-01, 9.0591961e-01, 6.7682409e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR26_IM-1090_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[3.9693032e-04, 1.4440244e-03, 2.3748972e-03, ...,
#           8.4372628e-01, 8.3438623e-01, 6.9263452e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR2504_IM-1029_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[1.7074744e-04, 1.4976010e-03, 2.1006970e-03, ...,
#           8.8305354e-01, 9.1890597e-01, 7.3019409e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR70_IM-2264_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[4.1210458e-07, 1.2649457e-03, 1.7959715e-03, ...,
#           8.4400958e-01, 8.2310367e-01, 6.8721259e-01]]], dtype=float32)>,
#  '/home/mxochicale/repositories/budai4medtech/amir/datasets/ecgen-radiology/CXR2208_IM-0815_0': <tf.Tensor: shape=(1, 1, 2048), dtype=float32, numpy=
#  array([[[6.1785179e-04, 1.5423362e-03, 3.3807543e-03, ...,
#           7.9313236e-01, 8.4261096e-01, 6.4677119e-01]]], dtype=float32)>,
#  ...}

# %%
# load the pre train GloVe token vector representations
embeddings_dict = {}
#with open("/content/drive/MyDrive/dissertation/glove.42B.300d.txt", 'r') as f:
with open("glove.42B.300d.txt", 'r') as f:
    for line in f:
        values = line.split()
        word = values[0]
        vector = np.asarray(values[1:], "float32")
        embeddings_dict[word] = vector

# %%
embeddings_dict["each"].shape
#use 300d tuple to represent "each" natural word.
# Out:
# (300,)

# %%
vocab_size = len(tokenizer.word_index.keys()) + 1

# %%
vocab_size
# Out:
# 1472

# %%
embedding_matrix = np.zeros((vocab_size,300))
for word, i in tokenizer.word_index.items():
    if word in embeddings_dict.keys():
        vec = embeddings_dict[word]
        embedding_matrix[i] = vec
    else:
        continue

# %%
def load_image(id_, report):
    '''Loads the Image Features with their corresponding Ids'''
    img_feature = Xnet_Features[id_.decode('utf-8')][0]
    return img_feature, report

# %%
BATCH_SIZE = 16
def create_dataset(img_name, caption):

    dataset = tf.data.Dataset.from_tensor_slices((img_name, caption))

  # Use map to load the numpy files in parallel
    dataset = dataset.map(lambda item1, item2: tf.numpy_function(load_image, [item1, item2], [tf.float32, tf.string]),
                          num_parallel_calls=tf.data.experimental.AUTOTUNE)

  # Shuffle and batch
    dataset = dataset.shuffle(500).batch(BATCH_SIZE).prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
    return dataset

# %%
train_generator = create_dataset(X_train, y_train)
cv_generator = create_dataset(X_cv, y_cv)

# %%
def bytes_to_string(arr):
    '''The generator gives provides data in bytes. This function converts them back to strings for manipulation'''
    for i in range(len(arr)):
        arr[i] = arr[i].decode('utf-8')
    return arr

# %%
#original
def convert(images, reports):
    '''This function takes the batch of data and converts them into a new dataset(A WORD BY WORD DATASET)'''
    imgs = []
    in_reports = []
    out_reports = []
    for i in range(len(images)):
        sequence = [tokenizer.word_index[e] for e in reports[i].split() if e in tokenizer.word_index.keys()]
      #  print(sequence)
      #This loop iterates over the indices of the images list. It retrieves the corresponding report from the reports
      #list using the index i. The report is then split into individual words using .split(). For each word e in the split report,
      #the code checks if it is present in the word_index of the tokenizer object. If it is, the corresponding word index is
      #retrieved and added to the sequence list.
        for j in range(1,len(sequence)):

            in_seq = sequence[:j]
            out_seq = sequence[j]
            out_seq = tf.keras.utils.to_categorical(out_seq, num_classes=vocab_size)

            imgs.append(images[i])
          #  print(in_seq)
            in_reports.append(in_seq)
           # print(out_seq)
            out_reports.append(out_seq)

    return np.array(imgs), np.array(in_reports), np.array(out_reports)

# %%
np.random.seed(42)

##fixing tensorflow RS
tf.random.set_seed(32)

##python RS
random.seed(12)

# %% [markdown]
# ## model without attention layer (only cnn + lstm rnn)

# %%
input1 = Input(shape=(2048,), name='Image_1')
dense1 = Dense(256, kernel_initializer=tf.keras.initializers.glorot_uniform(seed = 56), name='dense_encoder')(input1)

input2 = Input(shape=(153,), name='Text_Input')
emb_layer = Embedding(input_dim = vocab_size, output_dim = 300, input_length=153, mask_zero=True, trainable=False,
                weights=[embedding_matrix], name="Embedding_layer")
emb = emb_layer(input2)

LSTM1 = LSTM(units=256, activation='tanh', recurrent_activation='sigmoid', use_bias=True,
            kernel_initializer=tf.keras.initializers.glorot_uniform(seed=23),
            recurrent_initializer=tf.keras.initializers.orthogonal(seed=7),
            bias_initializer=tf.keras.initializers.zeros(), return_sequences=True, name="LSTM1")(emb)
#LSTM1_output = LSTM1(emb)
print("The shape of 'LSTM1' is " + str(LSTM1.shape))

LSTM2 = LSTM(units=256, activation='tanh', recurrent_activation='sigmoid', use_bias=True,
            kernel_initializer=tf.keras.initializers.glorot_uniform(seed=23),
            recurrent_initializer=tf.keras.initializers.orthogonal(seed=7),
            bias_initializer=tf.keras.initializers.zeros(), name="LSTM2")
LSTM2_output = LSTM2(LSTM1)

dropout1 = Dropout(0.6, name='dropout1')(LSTM2_output)


dec =  tf.keras.layers.Add()([dense1, dropout1])

fc1 = Dense(256, activation='relu', kernel_initializer=tf.keras.initializers.he_normal(seed = 63), name='fc1')
fc1_output = fc1(dec)
dropout2 = Dropout(0.5, name='dropout2')(fc1_output)
output_layer = Dense(vocab_size, activation='softmax', name='Output_layer')
output = output_layer(dropout2)


#output_layer(fc_1)

encoder_decoder = Model(inputs = [input1, input2], outputs = output)
encoder_decoder.summary()
# Out:
# The shape of 'LSTM1' is (None, 153, 256)
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Text_Input (InputLayer)        [(None, 153)]        0           []
#
#  Embedding_layer (Embedding)    (None, 153, 300)     441600      ['Text_Input[0][0]']
#
#  LSTM1 (LSTM)                   (None, 153, 256)     570368      ['Embedding_layer[0][0]']
#
#  Image_1 (InputLayer)           [(None, 2048)]       0           []
#
#  LSTM2 (LSTM)                   (None, 256)          525312      ['LSTM1[0][0]']
#
#  dense_encoder (Dense)          (None, 256)          524544      ['Image_1[0][0]']
#
#  dropout1 (Dropout)             (None, 256)          0           ['LSTM2[0][0]']
#
#  add (Add)                      (None, 256)          0           ['dense_encoder[0][0]',
#                                                                   'dropout1[0][0]']
#
#  fc1 (Dense)                    (None, 256)          65792       ['add[0][0]']
#
#  dropout2 (Dropout)             (None, 256)          0           ['fc1[0][0]']
#
#  Output_layer (Dense)           (None, 1472)         378304      ['dropout2[0][0]']
#
# ==================================================================================================
# Total params: 2,505,920
# Trainable params: 2,064,320
# Non-trainable params: 441,600
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(encoder_decoder)

# %% [markdown]
# ## model with self attention 1 (after text embedding and image imput)

# %%
#resouces: https://machinelearningmastery.com/encoder-decoder-attention-sequence-to-sequence-prediction-keras/
#https://machinelearningmastery.com/how-to-implement-multi-head-attention-from-scratch-in-tensorflow-and-keras/
#https://data-science-blog.com/blog/2021/04/07/multi-head-attention-mechanism/

# %%
input1 = Input(shape=(2048,), name='Image_1')

temp_mha = MultiHeadAttention(num_heads=4, d_model=2048)
out1, attn = temp_mha(v=input1, k=input1, q=input1, mask=None)

dense1 = Dense(256, kernel_initializer=tf.keras.initializers.glorot_uniform(seed = 56), name='dense_encoder')(out1)

dense1 = tf.keras.layers.Reshape((dense1.shape[-1],), name= "reshape")(dense1)

input2 = Input(shape=(153,), name='Text_Input')
emb_layer = Embedding(input_dim = vocab_size, output_dim = 300, input_length=153, mask_zero=True, trainable=False,
                weights=[embedding_matrix], name="Embedding_layer")
emb = emb_layer(input2)

#dense2 = Dense(256, kernel_initializer=tf.keras.initializers.glorot_uniform(seed = 56), name='dense_encoder2')(emb)

temp_mha = MultiHeadAttention(num_heads=4, d_model=300)
out2, attn = temp_mha(v=emb, k=emb, q=emb, mask=None)
#print(out.shape)

LSTM1 = LSTM(units=256, activation='tanh', recurrent_activation='sigmoid', use_bias=True,
            kernel_initializer=tf.keras.initializers.glorot_uniform(seed=23),
            recurrent_initializer=tf.keras.initializers.orthogonal(seed=7),
            bias_initializer=tf.keras.initializers.zeros(), return_sequences=True, name="LSTM1")(out2)
#LSTM1_output = LSTM1(emb)

LSTM2 = LSTM(units=256, activation='tanh', recurrent_activation='sigmoid', use_bias=True,
            kernel_initializer=tf.keras.initializers.glorot_uniform(seed=23),
            recurrent_initializer=tf.keras.initializers.orthogonal(seed=7),
            bias_initializer=tf.keras.initializers.zeros(), name="LSTM2")

LSTM2_output = LSTM2(LSTM1)

dropout1 = Dropout(0.4, name='dropout1')(LSTM2_output)


dec =  tf.keras.layers.Add()([dense1, dropout1])

fc1 = Dense(256, activation='relu', kernel_initializer=tf.keras.initializers.he_normal(seed = 63), name='fc1')
fc1_output = fc1(dec)
dropout2 = Dropout(0.4, name='dropout2')(fc1_output)
output_layer = Dense(vocab_size, activation='softmax', name='Output_layer')
output = output_layer(dropout2)
#output = tf.keras.layers.Reshape((output.shape[-1],))(output)
#output = tf.reshape(output , [output.shape[0], output.shape[-1]])

encoder_decoder = Model(inputs = [input1, input2], outputs = output)
encoder_decoder.summary()
# Out:
# 2023-07-24 19:09:41.073291: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-07-24 19:09:41.074837: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-07-24 19:09:41.077007: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Text_Input (InputLayer)        [(None, 153)]        0           []
#
#  Embedding_layer (Embedding)    (None, 153, 300)     441600      ['Text_Input[0][0]']
#
#  Image_1 (InputLayer)           [(None, 2048)]       0           []
#
#  multi_head_attention_1 (MultiH  ((None, None, 300),  361200     ['Embedding_layer[0][0]',
#  eadAttention)                   (None, 4, None, No               'Embedding_layer[0][0]',
#                                 ne))                              'Embedding_layer[0][0]']
#
#  multi_head_attention (MultiHea  ((None, None, 2048)  16785408   ['Image_1[0][0]',
#  dAttention)                    , (None, 4, None, N               'Image_1[0][0]',
#                                 one))                             'Image_1[0][0]']
#
#  LSTM1 (LSTM)                   (None, None, 256)    570368      ['multi_head_attention_1[0][0]']
#
#  dense_encoder (Dense)          (None, None, 256)    524544      ['multi_head_attention[0][0]']
#
#  LSTM2 (LSTM)                   (None, 256)          525312      ['LSTM1[0][0]']
#
#  reshape (Reshape)              (None, 256)          0           ['dense_encoder[0][0]']
#
#  dropout1 (Dropout)             (None, 256)          0           ['LSTM2[0][0]']
#
#  add_1 (Add)                    (None, 256)          0           ['reshape[0][0]',
#                                                                   'dropout1[0][0]']
#
#  fc1 (Dense)                    (None, 256)          65792       ['add_1[0][0]']
#
#  dropout2 (Dropout)             (None, 256)          0           ['fc1[0][0]']
#
#  Output_layer (Dense)           (None, 1472)         378304      ['dropout2[0][0]']
#
# ==================================================================================================
# Total params: 19,652,528
# Trainable params: 19,210,928
# Non-trainable params: 441,600
# __________________________________________________________________________________________________
# 2023-07-24 19:09:41.453880: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-07-24 19:09:41.455579: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-07-24 19:09:41.457174: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
tf.keras.utils.plot_model(encoder_decoder)

# %% [markdown]
# ## model with self attention 2 (after image imput)

# %%
input1 = Input(shape=(2048,), name='Image_1')
print(input1)
temp_mha = MultiHeadAttention(num_heads=4, d_model=2048)
out1, attn = temp_mha(v=input1, k=input1, q=input1, mask=None)

dense1 = Dense(256, kernel_initializer=tf.keras.initializers.glorot_uniform(seed = 56), name='dense_encoder')(out1)

dense1 = tf.keras.layers.Reshape((dense1.shape[-1],), name= "reshape")(dense1)

input2 = Input(shape=(153,), name='Text_Input')
emb_layer = Embedding(input_dim = vocab_size, output_dim = 300, input_length=153, mask_zero=True, trainable=True,
                weights=[embedding_matrix], name="Embedding_layer")
emb = emb_layer(input2)

#dense2 = Dense(256, kernel_initializer=tf.keras.initializers.glorot_uniform(seed = 56), name='dense_encoder2')(emb)

#temp_mha = MultiHeadAttention(num_heads=4, d_model=300)
#out2, attn = temp_mha(v=emb, k=emb, q=emb, mask=None)
#print(out.shape)

LSTM1 = LSTM(units=256, activation='tanh', recurrent_activation='sigmoid', use_bias=True,
            kernel_initializer=tf.keras.initializers.glorot_uniform(seed=23),
            recurrent_initializer=tf.keras.initializers.orthogonal(seed=7),
            bias_initializer=tf.keras.initializers.zeros(), return_sequences=True, name="LSTM1")(emb)
#LSTM1_output = LSTM1(emb)

LSTM2 = LSTM(units=256, activation='tanh', recurrent_activation='sigmoid', use_bias=True,
            kernel_initializer=tf.keras.initializers.glorot_uniform(seed=23),
            recurrent_initializer=tf.keras.initializers.orthogonal(seed=7),
            bias_initializer=tf.keras.initializers.zeros(), name="LSTM2")

LSTM2_output = LSTM2(LSTM1)

dropout1 = Dropout(0.6, name='dropout1')(LSTM2_output)


dec =  tf.keras.layers.Add()([dense1, dropout1])

fc1 = Dense(256, activation='relu', kernel_initializer=tf.keras.initializers.he_normal(seed = 63), name='fc1')
fc1_output = fc1(dec)
dropout2 = Dropout(0.5, name='dropout2')(fc1_output)
output_layer = Dense(vocab_size, activation='softmax', name='Output_layer')
output = output_layer(dropout2)
#output = tf.keras.layers.Reshape((output.shape[-1],))(output)
#output = tf.reshape(output , [output.shape[0], output.shape[-1]])

encoder_decoder = Model(inputs = [input1, input2], outputs = output)
encoder_decoder.summary()
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 2048), dtype=tf.float32, name='Image_1'), name='Image_1', description="created by layer 'Image_1'")
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Text_Input (InputLayer)        [(None, 153)]        0           []
#
#  Image_1 (InputLayer)           [(None, 2048)]       0           []
#
#  Embedding_layer (Embedding)    (None, 153, 300)     441600      ['Text_Input[0][0]']
#
#  multi_head_attention_1 (MultiH  ((None, None, 2048)  16785408   ['Image_1[0][0]',
#  eadAttention)                  , (None, 4, None, N               'Image_1[0][0]',
#                                 one))                             'Image_1[0][0]']
#
#  LSTM1 (LSTM)                   (None, 153, 256)     570368      ['Embedding_layer[0][0]']
#
#  dense_encoder (Dense)          (None, None, 256)    524544      ['multi_head_attention_1[0][0]']
#
#  LSTM2 (LSTM)                   (None, 256)          525312      ['LSTM1[0][0]']
#
#  reshape (Reshape)              (None, 256)          0           ['dense_encoder[0][0]']
#
#  dropout1 (Dropout)             (None, 256)          0           ['LSTM2[0][0]']
#
#  add_1 (Add)                    (None, 256)          0           ['reshape[0][0]',
#                                                                   'dropout1[0][0]']
#
#  fc1 (Dense)                    (None, 256)          65792       ['add_1[0][0]']
#
#  dropout2 (Dropout)             (None, 256)          0           ['fc1[0][0]']
#
#  Output_layer (Dense)           (None, 1472)         378304      ['dropout2[0][0]']
#
# ==================================================================================================
# Total params: 19,291,328
# Trainable params: 19,291,328
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(encoder_decoder)# plot the model

# %% [markdown]
# ## Training

# %%
optimizer = tf.keras.optimizers.Adam(0.0001)

# %%
loss_function = tf.keras.losses.CategoricalCrossentropy(from_logits=False, reduction='auto')
#from tensorflow.keras.losses import KLDivergence
#loss_function = KLDivergence()
def maskedLoss(y_true, y_pred):
    #getting mask value
    mask = tf.math.logical_not(tf.math.equal(y_true, 0))

    #calculating the loss
    loss_ = loss_function(y_true, y_pred)

    #converting mask dtype to loss_ dtype
    mask = tf.cast(mask, dtype=loss_.dtype)

    #applying the mask to loss
    loss_ = loss_*mask

    #getting mean over all the values
    loss_ = tf.reduce_mean(loss_)
    return loss_

# %%
encoder_decoder.compile(optimizer, loss = maskedLoss)

# %%
current_time = datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
train_log_dir = 'Tensorboard/logs_m1/fit3/' + current_time + '/train'
val_log_dir = 'Tensorboard/logs_m1/fit3/' + current_time + '/test'
train_summary_writer = tf.summary.create_file_writer(train_log_dir)
val_summary_writer = tf.summary.create_file_writer(val_log_dir)

# %% [markdown]
# Training for epochs 1-20

# %%
epoch_train_loss = []
epoch_val_loss = []
epoch_=40

for epoch in range(epoch_):
    print('EPOCH : ',epoch+1)
    start = time.time()
    batch_loss_tr = 0
    batch_loss_vl = 0

    for img, report in train_generator:

        r1 = bytes_to_string(report.numpy())
        img_input, rep_input, output_word = convert(img.numpy(), r1)
        rep_input = pad_sequences(rep_input, maxlen=153, padding='post')
        img_input=tf.reshape(img_input,shape=(img_input.shape[0],img_input.shape[-1]))
        results = encoder_decoder.train_on_batch([img_input, rep_input], output_word)

        batch_loss_tr += results

    train_loss = batch_loss_tr/(X_train.shape[0]//16)
    #14 is the batch size
    #   print('Saving Tensorboard')
    with train_summary_writer.as_default():
        tf.summary.scalar('loss', train_loss, step = epoch)

    for img, report in cv_generator:

        r1 = bytes_to_string(report.numpy())
        img_input, rep_input, output_word = convert(img.numpy(), r1)
        rep_input = pad_sequences(rep_input, maxlen=153, padding='post')
        img_input=tf.reshape(img_input,shape=(img_input.shape[0],img_input.shape[-1]))
        #output_word=tf.reshape(output_word,shape=(output_word.shape[0],output_word.shape[-1]))
        results = encoder_decoder.test_on_batch([img_input, rep_input], output_word)
        batch_loss_vl += results

    val_loss = batch_loss_vl/(X_cv.shape[0]//16)

    with val_summary_writer.as_default():
        tf.summary.scalar('loss', val_loss, step = epoch)

    epoch_train_loss.append(train_loss)

    epoch_val_loss.append(val_loss)

    print('Training Loss: {},  Val Loss: {}'.format(train_loss, val_loss))
    print('Time Taken for this Epoch : {} sec'.format(time.time()-start))
    encoder_decoder.save_weights('/content/drive/MyDrive/dissertation/Weights_re/embeddingTrain_onelayer_epoch_'+ str(epoch) + '.h5')
# Out:
# EPOCH :  1
# 2023-07-25 16:28:08.832842: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_1' with dtype string and shape [2776]
# 	 [[{{node Placeholder/_1}}]]
# 2023-07-25 16:28:08.833423: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_1' with dtype string and shape [2776]
# 	 [[{{node Placeholder/_1}}]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[92], line 14
#      11 for img, report in train_generator:
#      13     r1 = bytes_to_string(report.numpy())
# ---> 14     img_input, rep_input, output_word = convert(img.numpy(), r1)
#      15     rep_input = pad_sequences(rep_input, maxlen=153, padding='post')
#      16     img_input=tf.reshape(img_input,shape=(img_input.shape[0],img_input.shape[-1]))
#
# Cell In[84], line 26, in convert(images, reports)
#      23        # print(out_seq)
#      24         out_reports.append(out_seq)
# ---> 26 return np.array(imgs), np.array(in_reports), np.array(out_reports)
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (561,) + inhomogeneous part.

# %%
#load weight base=37 epoch
encoder_decoder.load_weights('/content/drive/MyDrive/dissertation/Weights_re/embeddingTrain_onelayer_epoch_9.h5')

# %%
# plot loss function
modelname=" (Base model)"
# Retrieve each dictionary's values
train_values = epoch_train_loss
val_values = epoch_val_loss

# Generate a sequence of integers to represent the epoch numbers
epochs = range(1, epoch_)

# Plot and label the training and validation loss values
plt.plot(epochs, train_values, label='Training Loss')
plt.plot(epochs, val_values, label='Validation Loss')

# Add in a title and axes labels
plt.title('Training and Validation Loss' +  modelname)
plt.xlabel('Epochs')
plt.ylabel('Loss')

# Set the tick locations
plt.xticks(arange(1, epoch_+1, 2))

# Display the plot
plt.legend(loc='best')
plt.show()

# %%
# plot loss function
modelname=" (self attention after image input)"
# Retrieve each dictionary's values
train_values = epoch_train_loss
val_values = epoch_val_loss

# Generate a sequence of integers to represent the epoch numbers
epochs = range(1, 60+1)

# Plot and label the training and validation loss values
plt.plot(epochs, train_values, label='Training Loss')
plt.plot(epochs, val_values, label='Validation Loss')

# Add in a title and axes labels
plt.title('Training and Validation Loss' +  modelname)
plt.xlabel('Epochs')
plt.ylabel('Loss')

# Set the tick locations
plt.xticks(arange(1, 60+1, 2))

# Display the plot
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ### Inference Setup

# %%
# base + one attention layer
# encoder
encoder_input = encoder_decoder.input[0]
#encoder_output = encoder_decoder.get_layer('dense_encoder').output
encoder_output = encoder_decoder.get_layer('reshape').output
#encoder_output = tf.reshape(image_features,shape=(image_features.shape[0],image_features.shape[-1]))
encoder_model = Model(encoder_input, encoder_output)

# decoder#
text_input = encoder_decoder.input[1]
enc_output = Input(shape=(256,), name='Enc_Output')
text_output = encoder_decoder.get_layer('LSTM2').output
add1 = tf.keras.layers.Add()([text_output, enc_output])
fc_1 = fc1(add1)
decoder_output = output_layer(fc_1)

decoder_model = Model(inputs = [text_input, enc_output], outputs = decoder_output)

# %% [markdown]
# ### Greedy Search

# %%
def greedysearch(img):
    image = Xnet_Features[img]
    image = tf.reshape(image,shape=(image.shape[0],image.shape[-1]))
    #image = tf.reshape(image,shape=(1,256))
    input_ = 'startseq'
    image_features = encoder_model.predict(image)
    #print(image_features.shape)

    result = []
    for i in range(153):
        input_tok = [tokenizer.word_index[w] for w in input_.split()]
        input_padded = pad_sequences([input_tok], 153, padding='post')
        image_features = tf.reshape(image_features,shape=(image_features.shape[0],image_features.shape[-1]))
        predictions = decoder_model.predict([input_padded, image_features])
        arg = np.argmax(predictions)
        if arg != 7:   # endseq
            result.append(tokenizer.index_word[arg])
            input_ = input_ + ' ' + tokenizer.index_word[arg]
        else:
            break
    rep = ' '.join(e for e in result)
    return rep

# %% [markdown]
# ### Beamsearch

# %%
def beamsearch(image, beam_width):

    start = [tokenizer.word_index['startseq']]

    sequences = [[start, 0]]

    img_features = Xnet_Features[image]
    img_features = tf.reshape(img_features,shape=(img_features.shape[0],img_features.shape[-1]))
    #image_features = tf.reshape(image_features,shape=(image_features.shape[0],image_features.shape[-1]))
    img_features = encoder_model.predict(img_features)
    finished_seq = []

    for i in range(153):
        all_candidates = []
        new_seq = []
        for s in sequences:

            text_input = pad_sequences([s[0]], 153, padding='post')
            text_input = tf.reshape(text_input,shape=(text_input.shape[0],text_input.shape[-1]))
            predictions = decoder_model.predict([text_input,img_features])
            top_words = np.argsort(predictions[0])[-beam_width:]
            seq, score = s

            for t in top_words:
                candidates = [seq + [t], score - np.log(predictions[0][t])]
                all_candidates.append(candidates)

        sequences = sorted(all_candidates, key = lambda l: l[1])[:beam_width]
        # checks for 'endseq' in each seq in the beam
        count = 0
        for seq,score in sequences:
            if seq[len(seq)-1] == tokenizer.word_index['endseq']:
                score = score/len(seq)   # normalized
                finished_seq.append([seq, score])
                count+=1
            else:
                new_seq.append([seq, score])
        beam_width -= count
        sequences = new_seq

        # if all the sequences reaches its end before 155 timesteps
        if not sequences:
            break
        else:
            continue

    sequences = finished_seq[-1]
    rep = sequences[0]
    score = sequences[1]
    temp = []
    rep.pop(0)
    for word in rep:
        if word != tokenizer.word_index['endseq']:
            temp.append(tokenizer.index_word[word])
        else:
            break
    rep = ' '.join(e for e in temp)

    return rep, score

# %% [markdown]
# ## Generate example reports and corresponding true report

# %%
image_atten_beam_output={
    "Image ID":[],
    "Generated report":[],
    "Original report":[]
}

for i in list(range(50)):

  image_atten_beam_output["Image ID"].append(X_test.values[i])
  image_atten_beam_output["Generated report"].append(beamsearch(X_test.values[i], 5)[0])
  image_atten_beam_output["Original report"].append(y_test.values[i])

image_atten_beam_output= pd.DataFrame(image_atten_beam_output)
image_atten_beam_output.to_csv('image_atten_beam_output.csv', index=False)

# %%
base_out={
    "Image ID":[],
    "Generated report":[],
    "Original report":[]
}

for i in list(range(len(X_test)-1)):

  base_out["Image ID"].append(X_test.values[i])
  base_out["Generated report"].append(greedysearch(X_test.values[i]))
  base_out["Original report"].append(y_test.values[i])

base_out= pd.DataFrame(base_out)
base_out.to_csv('base_output.csv', index=False)

# %%
# check some test data
res0 = greedysearch(X_test.values[0])
res1 = greedysearch(X_test.values[1])
res2 = greedysearch(X_test.values[2])
res12 = greedysearch(X_test.values[12])
res100 = greedysearch(X_test.values[100])
res111 = greedysearch(X_test.values[111])
res78 = greedysearch(X_test.values[78])
res90 = greedysearch(X_test.values[90])
res48 = greedysearch(X_test.values[48])
res8 = greedysearch(X_test.values[201])
res7 = greedysearch(X_test.values[72])

# %% [markdown]
# some example for base+attention

# %%
res1, res2, res12, res100, res111, res78, res90, res48, res8, res7
# Out:
# ('the heart size and pulmonary vascularity appear within normal limits . the lungs are free focal airspace disease . no pleural effusion pneumothora seen .',
#  'the heart size and pulmonary vascularity appear within normal limits . the lungs are free focal airspace disease . no pleural effusion pneumothora seen .',
#  'the heart normal size . the mediastinum unremarkable . the lungs are clear .',
#  'the heart size and mediastinal contours are within normal limits . the lungs are clear . no pneumothora pleural effusion .',
#  'the heart normal size . the mediastinum unremarkable . the lungs are clear .',
#  'the heart size and mediastinal contours are within normal limits . the lungs are clear . no pneumothora pleural effusion .',
#  'the heart size and pulmonary vascularity appear within normal limits . the lungs are free focal airspace disease . no pleural effusion pneumothora seen .',
#  'the heart size and mediastinal contours are within normal limits . the lungs are clear . no pneumothora pleural effusion .',
#  'the heart size and mediastinal contours are within normal limits . the lungs are clear . no pneumothora pleural effusion .',
#  'the heart size and pulmonary vascularity appear within normal limits . the lungs are free focal airspace disease . no pleural effusion pneumothora seen .')

# %% [markdown]
# generation reports through base model

# %%
res1, res2, res12, res100, res111, res78, res90, res48, res8, res7
# Out:
# ('the heart size normal . the mediastinum unremarkable . the lungs are clear .',
#  'the heart size and pulmonary vascularity appear within normal limits . the lungs are free focal airspace disease . no pleural effusion pneumothora seen .',
#  'the heart normal size . the mediastinum unremarkable . the lungs are clear .',
#  'the heart normal size . the mediastinum unremarkable . the lungs are clear .',
#  'the heart normal size . the mediastinum unremarkable . the lungs are clear .',
#  'the heart normal size . the mediastinum unremarkable . the lungs are clear .',
#  'the heart normal size . the mediastinum unremarkable . the lungs are clear .',
#  'the heart normal size . the mediastinum unremarkable . the lungs are clear .',
#  'the heart normal size . the mediastinum unremarkable . the lungs are clear .',
#  'the heart normal size . the mediastinum unremarkable . the lungs are clear .')

# %% [markdown]
# compare with true reports

# %%
#original reports
can0=y_test.values[0]
can1=y_test.values[1]
can2=y_test.values[2]
can12=y_test.values[12]
can100=y_test.values[100]
can111=y_test.values[111]
can78=y_test.values[78]
can90=y_test.values[90]
can48=y_test.values[48]
can8=y_test.values[201]
can7=y_test.values[72]

# %%
can0, can1, can12, can2, can100, can111, can78, can90, can48, can8, can7
# Out:
# ('startseq the cardio mediastinal silhouette pulmonary vascular pattern are within normal limits .  no pneumothora .  no pneumonia .  no pleural effusion .  mild degenerative changes mid thoracic spine .  endseq',
#  'startseq there no focal consolidation .  there no pneumothora large pleural effusion .  the cardiomediastinal contours are grossly unremarkable .  the heart size within normal limits .  endseq',
#  'startseq no focal consolidation .  there are prominent interstitial markings including focally right upper lobe which are similar from prior eamination .  no visualized pneumothora .  the heart size normal .  there are no pleural effusions .  endseq',
#  'startseq heart size moderately enlarged .  mild left costophrenic blunting .  streaky and patchy bibasilar opacities left greater than right .  right hemidiaphragm eventration noted .  no typical findings pulmonary edema .  endseq',
#  'startseq no focal consolidation pneumothora definite pleural effusion .  heart size within normal limits for technique no mediastinal widening seen .  no acute osseous injury demonstrated .  detroscoliosis noted .  endseq',
#  'startseq there airspace disease the right lower lobe seen behind the right hemidiaphragm view .  this also well seen lateral view .  remainder the lungs appear clear .  the heart and pulmonary appear normal .  mediastinal contours are normal .  endseq',
#  'startseq heart size normal .  lungs are clear .  are normal .  no pneumonia effusions edema pneumothora adenopathy nodules masses .  endseq',
#  'startseq the heart normal size .  the mediastinum stable .  right chest tip again seen the cavoatrial junction .  there no pneumothora .  there again elevation right hemidiaphragm with rightsided pleural effusion .  vague opacities are noted the right upper lobe from prior study .  these may related overlying rib lesions versus true pulmonary nodules .  the left lung appears grossly clear .  drainage catheter seen overlying the right upper quadrant .  endseq',
#  'startseq the heart and mediastinal contours are stable .  the lungs are clear without focal infiltrate .  there no pleural effusion pneumothora .  endseq',
#  'startseq there are no acute osseous abnormalities .  there are surgical clips the right upper abdomen from cholecystectomy .  normal heart size .  normal hilar vascular markings .  the lungs are grossly clear without focal area consolidation pleural effusion pneumothora .  endseq',
#  'startseq the heart normal size and contour .  there no mediastinal widening .  the lungs are clear bilaterally .  no large pleural effusion pneumothora .  the are intact .  endseq')

# %% [markdown]
# # evaluation score
#
# Surface-form similarity:
# Bleu score is precision-based. It calculates n-gram overlap between the candidate and the reference.The key idea of BLEU is to compute precision by clipping.
#
# Cider score is an image captioning metric that computes cosine similarity between tf–idf weighted n-grams.
#
# ROUGE score is recall base. It computes n-gram based recall for the candidate sentence with respect to the references.
#
# Semantics-form similarity:
# Berts score computes the similarity between their tokens' embeddings.

# %% [markdown]
# ### BLEU SCORE

# %%
def rem_fullstops(text):
    '''Removes punctuations'''
    punctuations = '''.''' # full stop is not removed
    new_text = []
    for char in text:
        if char in punctuations:
            text = text.replace(char, "")
    new_text.append(' '.join(e for e in text.split()))
    return new_text[0]

# %% [markdown]
# ### CIDER SCORE

# %%
import math
def calculate_cider(reference_sentence, candidate_sentence):
    # Preprocess the sentences
    reference_tokens = nltk.word_tokenize(reference_sentence.lower())
    candidate_tokens = nltk.word_tokenize(candidate_sentence.lower())

    # Compute term frequency (TF) for candidate tokens
    term_frequency = nltk.FreqDist(candidate_tokens)

    # Compute document frequency (DF) for the reference tokens
    document_frequency = nltk.FreqDist(reference_tokens)

    # Compute inverse document frequency (IDF) for each token
    inverse_document_frequency = {
        token: math.log2(len(reference_tokens) / (document_frequency[token] + 1))
        for token in set(reference_tokens)
    }

    # Calculate TF-IDF scores and CIDEr score
    cider_score = 0
    for token in candidate_tokens:
        tf_idf = term_frequency[token] * inverse_document_frequency.get(token, 0)
        cider_score += tf_idf

    cider_score /= len(candidate_tokens)

    return cider_score

# Example usage
reference_sentence = "A cat is sitting on a mat."
candidate_sentence = "A cat is sleeping on a mat."

cider_score = calculate_cider(reference_sentence, candidate_sentence)
print("CIDEr Score:", cider_score)
# Out:
# CIDEr Score: 1.957518749639422

# %% [markdown]
# ### ROUGE-L SCORE

# %%
def calculate_rouge_l(reference_summary, generated_summary):
    rouge = Rouge()
    scores = rouge.get_scores(generated_summary, reference_summary)
    rouge_l_score = scores[0]['rouge-l']['f']
    return rouge_l_score

# %% [markdown]
# ### Bert Score

# %%
# !pip install torchmetrics
# !pip install transformers

# %%
from torchmetrics.text.bert import BERTScore

# %%
bertscore = BERTScore()
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/482 [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %% [markdown]
# # Calculate evaluation scores

# %% [markdown]
# ## CV dataset

# %%
bleu1 = []
bleu2 = []
bleu3 = []
bleu4 = []
cider = []
rouge_l = []
bert_score = []
for img, rep in tqdm(zip(X_cv.values, y_cv.values)):

    rep = rem_fullstops(rep)
    rep = rep.split()[1:]
    rep = rep[:len(rep)- 1]
    rep = ' '.join(e for e in rep)

    pred_rep = greedysearch(img)
    pred_rep = rem_fullstops(pred_rep)
    print(rep, pred_rep)
    bleu1.append(sentence_bleu([rep.split()], pred_rep.split(), weights = (1,0,0,0)))
    bleu2.append(sentence_bleu([rep.split()], pred_rep.split(), weights = (0.5,0.5,0,0)))
    bleu3.append(sentence_bleu([rep.split()], pred_rep.split(), weights = (0.33,0.33,0.33,0)))
    bleu4.append(sentence_bleu([rep.split()], pred_rep.split(), weights = (0.25,0.25,0.25,0.25)))
    cider.append(calculate_cider(rep, pred_rep))
    rouge_l.append(calculate_rouge_l(rep, pred_rep))
    score= bertscore(rep, pred_rep)
    bert_score.append(score["f1"])

# %%
print('Bleu1 Score: ', sum(bleu1)/X_cv.shape[0])
print('Bleu2 Score: ', sum(bleu2)/X_cv.shape[0])
print('Bleu3 Score: ', sum(bleu3)/X_cv.shape[0])
print('Bleu4 Score: ', sum(bleu4)/X_cv.shape[0])
print('cider: ', sum(cider)/X_cv.shape[0])
print('rouge_l: ', sum(rouge_l)/X_cv.shape[0])
# Out:
# Bleu1 Score:  0.21297539821221598
# Bleu2 Score:  0.11821994264992028
# Bleu3 Score:  0.07606061645830485
# Bleu4 Score:  0.03903942309785743
# cider:  nan
# rouge_l:  0.2703140104566871

# %% [markdown]
# ## Test dataset

# %% [markdown]
# how can I evaluate the performance of model?
# -not only the evaluation metrix
# -different paper has total different evaluation metric reuslt, looks unreasonable (intiger or present? If present, score looks reasonable)

# %%
bleu1 = []
bleu2 = []
bleu3 = []
bleu4 = []
cider = []
rouge_l = []
bert_score = []
for img, rep in tqdm(zip(X_test.values[:100], y_test.values[:100])):

    rep = rem_fullstops(rep)
    rep = rep.split()[1:]
    rep = rep[:len(rep)-1]
    rep = ' '.join(e for e in rep)

    #pred_rep = greedysearch(img)
    pred_rep = beamsearch(img, 5)
    pred_rep= str(pred_rep)
    #pred_rep = rem_fullstops(pred_rep)

    bleu1.append(sentence_bleu([rep.split()], pred_rep.split(), weights = (1,0,0,0)))
    bleu2.append(sentence_bleu([rep.split()], pred_rep.split(), weights = (0.5,0.5,0,0)))
    bleu3.append(sentence_bleu([rep.split()], pred_rep.split(), weights = (0.33,0.33,0.33,0)))
    bleu4.append(sentence_bleu([rep.split()], pred_rep.split(), weights = (0.25,0.25,0.25,0.25)))
    cider.append(calculate_cider(rep, pred_rep))
    rouge_l.append(calculate_rouge_l(rep, pred_rep))
    #score= bertscore(rep, pred_rep)
    #bert_score.append(score["f1"])
# Out:
# 0it [00:00, ?it/s]
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1it [00:17, 17.27s/it]
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 2it [00:26, 12.79s/it]
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 21ms/step
# 3it [00:37, 11.99s/it]
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 4it [00:47, 11.20s/it]
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 5it [00:56, 10.40s/it]
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 6it [01:07, 10.43s/it]
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# ...
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 98it [15:55, 10.29s/it]
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 99it [16:06, 10.75s/it]
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 32ms/step
# 100it [16:16,  9.77s/it]

# %%
print('Bleu1 Score: ', sum(bleu1)/99)
print('Bleu2 Score: ', sum(bleu2)/99)
print('Bleu3 Score: ', sum(bleu3)/99)
print('Bleu4 Score: ', sum(bleu4)/99)
print('cider: ', sum(cider)/99)
print('rouge_l: ', sum(rouge_l)/99)
# Out:
# Bleu1 Score:  0.3133607626174864
# Bleu2 Score:  0.17939025193937724
# Bleu3 Score:  0.09443922802948299
# Bleu4 Score:  0.023484059114847602
# cider:  1.26864347275316
# rouge_l:  0.3542688801375284
